# %% [markdown]
# ## Automatic File Sorter in File Explorer

# %% [markdown]
# #####

# %%
import os, shutil

# %%
path = r"H:/when they ask for my transcript/"

# %%
file_name = os.listdir(path)

# %%
folder_names = ['csv files', 'large files', 'text files', 'pdf files', 'docx files', 'image files']

for loop in range(0,6):
    if not os.path.exists(path + folder_names[loop]):
       print(path + folder_names[loop])
       os.makedirs(path + folder_names[loop])

for file in file_name:
    if ".csv" in file and not os.path.exists(path + 'csv files/' + file):
       shutil.move(path + file, path + 'csv files/' + file)
    elif ".PNG" in file and not os.path.exists(path + 'image files/' + file):
       shutil.move(path + file, path + 'image files/' + file)
    elif ".xlsx" in file and not os.path.exists(path + 'text files/' + file):
       shutil.move(path + file, path + 'text files/' + file)
    if ".pdf" in file and not os.path.exists(path + 'pdf files/' + file):
       shutil.move(path + file, path + 'pdf files/' + file)
    if ".docx" in file and not os.path.exists(path + 'docx files/' + file):
       shutil.move(path + file, path + 'docx files/' + file)
    else:
        print("There are files in this path that were not moved!")
# Out:
# H:/when they ask for my transcript/csv files
# H:/when they ask for my transcript/large files
# H:/when they ask for my transcript/text files
# H:/when they ask for my transcript/pdf files
# H:/when they ask for my transcript/docx files
# H:/when they ask for my transcript/image files
# There are files in this path that were not moved!
# There are files in this path that were not moved!
# There are files in this path that were not moved!
# There are files in this path that were not moved!
# There are files in this path that were not moved!
# There are files in this path that were not moved!
# There are files in this path that were not moved!
# There are files in this path that were not moved!
# There are files in this path that were not moved!
# There are files in this path that were not moved!
# There are files in this path that were not moved!
# There are files in this path that were not moved!
# There are files in this path that were not moved!
# There are files in this path that were not moved!
# There are files in this path that were not moved!
# There are files in this path that were not moved!
# There are files in this path that were not moved!
# There are files in this path that were not moved!
# There are files in this path that were not moved!
# There are files in this path that were not moved!
# There are files in this path that were not moved!
# There are files in this path that were not moved!
# There are files in this path that were not moved!
# There are files in this path that were not moved!
# There are files in this path that were not moved!
